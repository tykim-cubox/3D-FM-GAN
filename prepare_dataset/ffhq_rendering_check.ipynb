# %%
from pathlib import Path
from PIL import Image

# %%
img_path_list  = list(Path('/workspace/gan/3D-FM-GAN/data/ffhq/images').rglob('*.png'))
len(img_path_list)

# /workspace/gan/3D-FM-GAN/data/ffhq/rendering
# Out:
# 70000

# %%
img_path_list = sorted(img_path_list)

# %%
for i, img_path in zip(range(70000), img_path_list):
  if i != int(img_path.stem):
    print('dasd')

# %%
rnd_path_list  = list(Path('/workspace/gan/3D-FM-GAN/data/ffhq/rendering').rglob('*.png'))
len(rnd_path_list)
# Out:
# 70000

# %%
rnd_path_list = sorted(rnd_path_list)

# %%
for p, r in zip(img_path_list, rnd_path_list):
  Image.open(p)
  Image.open(r)

  break

# %%
Image.open(img_path_list[3000]).size
# Out:
# (224, 224)

# %%
Image.open(rnd_path_list[3000])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x7F00ECCA3D30>
