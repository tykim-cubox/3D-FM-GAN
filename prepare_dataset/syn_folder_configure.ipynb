# %%
from pathlib import Path
from PIL import Image
import shutil

# %%
disco_rnd_list = list(Path('/home/aiteam/tykim/temp/disco').rglob('*_r.png'))
disco_pic_list = list(Path('/home/aiteam/tykim/temp/disco').rglob('*[!_r!_m].png'))

# %%
len(disco_rnd_list), len(disco_pic_list)
# Out:
# (70000, 70000)

# %%
rnd_path = Path('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data', 'rendering')
rnd_path.mkdir(exist_ok=True)

pic_path = Path('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data', 'images')
pic_path.mkdir(exist_ok=True)

# %%
disco_pic_list[0].parts[-1]
# Out:
# '2291_05.png'

# %%
disco_pic_list[0]
# Out:
# PosixPath('/home/aiteam/tykim/temp/disco/2291_05.png')

# %%
rnd_path.joinpath(disco_pic_list[0].parts[-1])
# Out:
# PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/2291_05.png')

# %%
for rnd in disco_rnd_list:
  # dst = rnd_path.joinpath(rnd.parts[-1])
  shutil.copy(rnd, rnd_path) # rnd_path.joinpath(dst)

for pic in disco_pic_list:
  shutil.copy(pic, pic_path)

# %%
test = list(Path('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering').rglob('*.png'))

test2 = list(Path('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images').rglob('*.png'))

# %%
len(test)
# Out:
# 70000

# %%
test = sorted(test)
test[:10]
# Out:
# [PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_0_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_1_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_2_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_3_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_4_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_5_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_6_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/1000_0_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/1000_1_r.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/1000_2_r.png')]

# %%
print(test[1])
Image.open(test[1])
# Out:
# /home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/rendering/0_1_r.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
test2 = sorted(test2)

# %%
test2[:10]
# Out:
# [PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_00.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_01.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_02.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_03.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_04.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_05.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/000_06.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/001_00.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/001_01.png'),
#  PosixPath('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/images/001_02.png')]

# %%
Image.open(test2[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
len(test2)
# Out:
# 70000

# %%
len(test)
# Out:
# 70000

# %%
m_list = list(Path('/home/aiteam/tykim/generative/gan/3D-FM-GAN/data/syn_data/mask').rglob('*.png'))

# %%
m_list = sorted(m_list)

# %%
Image.open(m_list[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
